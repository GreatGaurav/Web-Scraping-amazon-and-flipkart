# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
page = requests.get('https://www.flipkart.com/l-avenir-gym-fitness-3ft-straight-rod-biceps-triceps-exercise-locks-weight-lifting-bar/product-reviews/itmd3a08111dacea?pid=BAAFF5457NGUXAVT&lid=LSTBAAFF5457NGUXAVTWYXKZN&marketplace=FLIPKART')

# %%
page.content
# Out:
# b'<!doctype html><html lang="en"><head><link href="https://rukminim1.flixcart.com" rel="preconnect"/><link rel="stylesheet" href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.07395f.css"/><meta http-equiv="Content-type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=Edge"/><meta property="fb:page_id" content="102988293558"/><meta property="fb:admins" content="658873552,624500995,100000233612389"/><meta name="robots" content="noodp"/><link rel="shortcut icon" href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico"/><link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/><meta property="og:type" content="website"/><meta name="og_site_name" property="og:site_name" content="Flipkart.com"/><link rel="apple-touch-icon" sizes="57x57" href="/apple-touch-icon-57x57.png"/><link rel="apple-touch-icon" sizes="72x72" href="/apple-touch-icon-72x72.png"/><link rel="app
# ...

# %%
soup = bs(page.content, 'html.parser')

# %%
print(soup.title.text)
# Out:
# L Avenir Gym Fitness 3ft Straight Rod Biceps Triceps Exercise Locks Weight Lifting Bar Reviews: Latest Review of L Avenir Gym Fitness 3ft Straight Rod Biceps Triceps Exercise Locks Weight Lifting Bar | Price in India | Flipkart.com

# %%
reviews = soup.find_all('div', {'class':'col _2wzgFH K0kLPL'})

# %%
for item in reviews:
    product = soup.title.text.replace('| Price in India | Flipkart.com', '')
    title = item.find('p').text
    body = item.find('div', {'class':'t-ZTKy'}).text.strip()
    user = item.find('p',{'class':'_2sc7ZR _2V5EHH'}).text
#     rating = float(item.find('div', {'class':'_3LWZlK _1BLPMq'}).text)
    print(body+ '\t'+user+'\n')
    print(product)
# Out:
# Rod is too thin and small . Its an average product. Expections not met reality i think the weight is ok and the locks of this rod is so poor and not fix in the rod easily it will requires too much hard to fix in the rod . Atlast i say that it is good for begginers at for who who wants to workout at home if you are a intermediate just go for 5ft branded rod atleast it will give u value for moneyREAD MORE	Tanishq Gupta
#
# L Avenir Gym Fitness 3ft Straight Rod Biceps Triceps Exercise Locks Weight Lifting Bar Reviews: Latest Review of L Avenir Gym Fitness 3ft Straight Rod Biceps Triceps Exercise Locks Weight Lifting Bar
# goodREAD MORE	Flipkart Customer
#
# L Avenir Gym Fitness 3ft Straight Rod Biceps Triceps Exercise Locks Weight Lifting Bar Reviews: Latest Review of L Avenir Gym Fitness 3ft Straight Rod Biceps Triceps Exercise Locks Weight Lifting Bar
# superREAD MORE	Sairam Mandalapu
#
# ...
